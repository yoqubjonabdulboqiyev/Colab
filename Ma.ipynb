# %% [markdown]
# <a href="https://colab.research.google.com/github/Zaripov2004/Test/blob/main/Ma.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 📊 Dunyo iqlim o‘zgarishi va ekologiya statistikasi
#
#
# 1-bosqich: Loyiha nomi
#
# Dunyo iqlim o‘zgarishi va ekologiya statistikasi (1880–2024)

# %% [markdown]
# 2-bosqich: Ma’lumot manbalari
#
# IPCC Reports (AR6) – global iqlim prognozlari va ssenariylari
#
# NASA GISS Surface Temperature Analysis (GISTEMP v4) – 1880 yildan hozirgacha global harorat o‘zgarishi
#
# NOAA Global Climate Data – okean sathi, atmosfera CO₂ darajalari
#
# World Bank Climate Data – ekologik ko‘rsatkichlar

# %% [markdown]
# 3-bosqich: Maqsad
#
# Dunyo bo‘yicha harorat, CO₂ konsentratsiyasi va okean sathi o‘zgarishini tahlil qilish.
#
# IPCC prognozlari asosida 2100 yilgacha iqlim ssenariylarini ko‘rsatish.
#
# Ekologik oqibatlarni baholash va tavsiyalar berish.

# %% [markdown]
# 4-bosqich: Kutubxonalarni chaqirish

# %%
import pandas as pd
import matplotlib.pyplot as plt
import requests

# %% [markdown]
# 5-bosqich: NASA Climate Data – Harorat o‘zgarishi (demo ma’lumot)

# %%
data_temp = {
    1880: -0.2, 1900: -0.1, 1920: 0.0, 1940: 0.1,
    1960: 0.0, 1980: 0.3, 2000: 0.6, 2010: 0.9, 2020: 1.2, 2024: 1.3
}
df_temp = pd.DataFrame.from_dict(data_temp, orient="index", columns=["Temp_Anomaly"])
df_temp.index.name = "Year"
df_temp.head()
# Out:
#       Temp_Anomaly
# Year
# 1880          -0.2
# 1900          -0.1
# 1920           0.0
# 1940           0.1
# 1960           0.0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Temp_Anomaly'].plot(kind='hist', bins=20, title='Temp_Anomaly')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_1['Temp_Anomaly'].plot(kind='line', figsize=(8, 4), title='Temp_Anomaly')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# 6-bosqich: Harorat grafigi

# %%
plt.figure(figsize=(10,6))
plt.plot(df_temp.index, df_temp["Temp_Anomaly"], marker='o', color="red")
plt.title("Global o‘rtacha harorat anomaliyalari (1880–2024, NASA GISS)")
plt.xlabel("Yil")
plt.ylabel("°C (bazaviy davrga nisbatan)")
plt.grid(True)
plt.show()

# %% [markdown]
# 7-bosqich: CO₂ konsentratsiyasi (Mauna Loa Observatory, 1958–2024)

# %%
data_co2 = {
    1960: 317, 1980: 338, 2000: 370, 2010: 390, 2020: 414, 2024: 421
}
df_co2 = pd.DataFrame.from_dict(data_co2, orient="index", columns=["CO2_ppm"])
df_co2.index.name = "Year"
df_co2
# Out:
#       CO2_ppm
# Year
# 1960      317
# 1980      338
# 2000      370
# 2010      390
# 2020      414
# 2024      421
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df_co2['CO2_ppm'].plot(kind='hist', bins=20, title='CO2_ppm')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['CO2_ppm']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'CO2_ppm'}, axis=1)
#               .sort_values('CO2_ppm', ascending=True))
# ...

# %% [markdown]
# 8-bosqich: CO₂ grafigi

# %%
plt.figure(figsize=(10,6))
plt.plot(df_co2.index, df_co2["CO2_ppm"], marker='o', color="green")
plt.title("Atmosfera CO₂ darajasi (ppm, 1960–2024)")
plt.xlabel("Yil")
plt.ylabel("CO₂ (ppm)")
plt.grid(True)
plt.show()

# %% [markdown]
# 9-bosqich: Okean sathi (NOAA)

# %%
data_sea = {
    1900: 0, 1950: 5, 2000: 15, 2020: 22, 2024: 25
}
df_sea = pd.DataFrame.from_dict(data_sea, orient="index", columns=["Sea_Level (cm)"])
df_sea.index.name = "Year"
df_sea
# Out:
#       Sea_Level (cm)
# Year
# 1900               0
# 1950               5
# 2000              15
# 2020              22
# 2024              25
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df_sea['Sea_Level (cm)'].plot(kind='hist', bins=20, title='Sea_Level (cm)')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['Sea_Level (cm)']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'Sea_Level (cm)'}, axis=1)
# ...

# %% [markdown]
# 10-bosqich: IPCC prognozlari (RCP ssenariylar)

# %%
scenarios = {
    "RCP2.6": [1.5, 1.6, 1.7, 1.8],
    "RCP4.5": [1.6, 2.0, 2.4, 2.6],
    "RCP8.5": [1.8, 2.7, 3.8, 4.5]
}
years = [2030, 2050, 2075, 2100]
df_ipcc = pd.DataFrame(scenarios, index=years)
df_ipcc
# Out:
#       RCP2.6  RCP4.5  RCP8.5
# 2030     1.5     1.6     1.8
# 2050     1.6     2.0     2.7
# 2075     1.7     2.4     3.8
# 2100     1.8     2.6     4.5
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df_ipcc['RCP2.6'].plot(kind='hist', bins=20, title='RCP2.6')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df_ipcc['RCP4.5'].plot(kind='hist', bins=20, title='RCP4.5')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df_ipcc['RCP8.5'].plot(kind='hist', bins=20, title='RCP8.5')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# ...

# %% [markdown]
# 11-bosqich: Prognoz grafiklari

# %%
plt.figure(figsize=(10,6))
for col in df_ipcc.columns:
    plt.plot(df_ipcc.index, df_ipcc[col], marker='o', label=col)
plt.title("IPCC prognozlari – Global harorat o‘zgarishi (°C, 2030–2100)")
plt.xlabel("Yil")
plt.ylabel("Harorat (°C)")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# 12-bosqich: Natijalar
#
# 1880 yildan 2024 yilgacha harorat ~ 1.3°C ga ko‘tarildi.
#
# CO₂ darajasi sanoat inqilobidan beri 280 ppm dan 421 ppm ga yetdi.
#
# Okean sathi 20-asr davomida ~ 25 sm ko‘tarilgan.
#
# IPCC prognozlariga ko‘ra, 2100 yilgacha global harorat 1.8°C–4.5°C gacha ko‘tarilishi mumkin.

# %% [markdown]
# 13-bosqich: Umumiy xulosa
#
# XX asr oxiridan beri inson faoliyati natijasida iqlim o‘zgarishi tezlashdi. NASA va IPCC ma’lumotlari shuni ko‘rsatadiki:
#
# Atmosfera CO₂ darajasining oshishi global haroratning ko‘tarilishiga sabab bo‘lmoqda.
#
# Okean sathi ko‘tarilishi qirg‘oqbo‘yi hududlarga xavf tug‘diradi.
#
# Prognozlarga ko‘ra, agar keskin choralar ko‘rilmasa, 2100 yilgacha harorat xavfli darajaga chiqishi mumkin.
#
# 👉 Shu bois, barqaror energiya manbalariga o‘tish, o‘rmonlarni muhofaza qilish va xalqaro ekologik hamkorlik global siyosatda ustuvor yo‘nalish bo‘lishi shart.
